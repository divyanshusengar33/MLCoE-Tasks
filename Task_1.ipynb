# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("tech_job_market_2019_2026.csv")

# %%
df.head(10)
# Out:
#       job_id              company_name company_type         sector  \
# 0  JOB041385              CobaltWealth          MNC     HealthTech
# 1  JOB018462                DriftLearn     Mid-size    Cloud/Infra
# 2  JOB110011           AnchorBuzz Labs          MNC     HealthTech
# 3  JOB073462                KiteSphere      Unicorn     HealthTech
# 4  JOB051683             AetherNode Co          MNC  Social/AdTech
# 5  JOB099770  QuantumBuzz Technologies          MNC           SaaS
# 6  JOB080320                SpireCloud          MNC        Fintech
# 7  JOB057551             EchoCortex Co          MNC  Cybersecurity
# 8  JOB019108                NimbusFlow   FAANG-tier    Crypto/Web3
# 9  JOB088302      VantageChain Systems      Startup          AI/ML
#
#    company_size_employees hq_country                   job_role  \
# 0                  146085    Germany                SOC Analyst
# 1                    5882        USA      Mobile Engineer (iOS)
# 2                  186507        USA                QA Engineer
# 3                   10930     Brazil         Research Scientist
# 4                   42510        USA            Product Manager
# 5                   86535         UK              Data Engineer
# 6                  369939        USA                UI Designer
# 7                  128882        USA  Embedded Systems Engineer
# 8                   53256         UK           Product Designer
# 9                     380     Brazil           Product Designer
#
#   seniority_level  years_experience_min  years_experience_max  ...  \
# 0             Mid                     3                     5  ...
# 1             Mid                     1                     4  ...
# 2            Lead                     7                    15  ...
# 3           Entry                     1                     4  ...
# 4          Senior                     6                     9  ...
# 5          Intern                     1                     1  ...
# 6           Entry                     0                     1  ...
# 7           Entry                     0                     4  ...
# 8             Mid                     1                     5  ...
# 9          Intern                     0                     0  ...
#
#   application_deadline date_position_filled position_status  \
# 0  2023-11-12 00:00:00           2023-11-20          Filled
# 1  2025-06-29 00:00:00                  NaN            Open
# 2  2026-01-24 00:00:00           2026-02-08          Filled
# 3  2020-12-09 00:00:00           2020-12-21          Filled
# 4  2025-07-19 00:00:00           2025-09-15          Filled
# 5  2025-09-09 00:00:00           2025-09-09          Filled
# 6  2022-06-16 00:00:00           2022-06-09          Filled
# 7  2024-05-25 00:00:00           2024-05-29          Filled
# 8  2022-04-21 00:00:00           2022-08-17          Filled
# 9  2025-05-23 00:00:00           2025-05-05          Filled
#
#   number_of_applicants number_of_interview_rounds offers_extended  \
# 0                 98.0                        4.0             5.0
# 1                134.0                        2.0             1.0
# 2                 36.0                        4.0             1.0
# 3                300.0                        1.0             6.0
# 4                 43.0                        3.0             1.0
# 5                 58.0                        2.0             1.0
# 6                281.0                        1.0             1.0
# 7                258.0                        3.0             1.0
# 8                 78.0                        4.0             1.0
# 9                349.0                        3.0             1.0
#
#   offers_accepted salary_min_usd salary_max_usd layoff_within_12_months_flag
# 0             5.0             -1             -1                            N
# 1             0.0            NaN            NaN                           No
# 2             1.0       238800.0       274700.0                            0
# 3             5.0        96300.0       104000.0                          Yes
# 4             1.0       $186,800       245400.0                            1
# 5             1.0        33100.0        38500.0                           No
# 6             3.0        87400.0        98100.0                        False
# 7             1.0       131100.0       103900.0                            N
# 8             1.0       114500.0       139700.0                            0
# 9             1.0        42500.0        47600.0                        False
#
# [10 rows x 28 columns]

# %%
df.shape
# Out:
# (115000, 28)

# %%
print(df.columns)
# Out:
# Index(['job_id', 'company_name', 'company_type', 'sector',
#        'company_size_employees', 'hq_country', 'job_role', 'seniority_level',
#        'years_experience_min', 'years_experience_max', 'required_tech_stack',
#        'primary_programming_language', 'work_mode', 'visa_sponsorship_offered',
#        'job_location_country', 'job_location_city', 'salary_currency',
#        'posting_date', 'application_deadline', 'date_position_filled',
#        'position_status', 'number_of_applicants', 'number_of_interview_rounds',
#        'offers_extended', 'offers_accepted', 'salary_min_usd',
#        'salary_max_usd', 'layoff_within_12_months_flag'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# job_id                           object
# company_name                     object
# company_type                     object
# sector                           object
# company_size_employees            int64
# hq_country                       object
# job_role                         object
# seniority_level                  object
# years_experience_min              int64
# years_experience_max              int64
# required_tech_stack              object
# primary_programming_language     object
# work_mode                        object
# visa_sponsorship_offered         object
# job_location_country             object
# job_location_city                object
# salary_currency                  object
# posting_date                     object
# application_deadline             object
# date_position_filled             object
# position_status                  object
# number_of_applicants            float64
# number_of_interview_rounds      float64
# offers_extended                 float64
# offers_accepted                 float64
# salary_min_usd                   object
# salary_max_usd                   object
# layoff_within_12_months_flag     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115000 entries, 0 to 114999
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   job_id                        115000 non-null  object
#  1   company_name                  115000 non-null  object
#  2   company_type                  115000 non-null  object
#  3   sector                        115000 non-null  object
#  4   company_size_employees        115000 non-null  int64
#  5   hq_country                    115000 non-null  object
#  6   job_role                      115000 non-null  object
#  7   seniority_level               115000 non-null  object
#  8   years_experience_min          115000 non-null  int64
#  9   years_experience_max          115000 non-null  int64
#  10  required_tech_stack           115000 non-null  object
#  11  primary_programming_language  92525 non-null   object
#  12  work_mode                     115000 non-null  object
#  13  visa_sponsorship_offered      115000 non-null  object
#  14  job_location_country          115000 non-null  object
#  15  job_location_city             89893 non-null   object
#  16  salary_currency               115000 non-null  object
#  17  posting_date                  115000 non-null  object
#  18  application_deadline          109243 non-null  object
#  19  date_position_filled          89219 non-null   object
#  20  position_status               115000 non-null  object
#  21  number_of_applicants          113890 non-null  float64
#  22  number_of_interview_rounds    114564 non-null  float64
#  23  offers_extended               114670 non-null  float64
#  24  offers_accepted               114670 non-null  float64
#  25  salary_min_usd                111682 non-null  object
#  26  salary_max_usd                111682 non-null  object
#  27  layoff_within_12_months_flag  115000 non-null  object
# dtypes: float64(4), int64(3), object(21)
# memory usage: 24.6+ MB

# %% [markdown]
# So, basically there are 3 int columns,4 float columns,21 objects columns

# %%
df.describe()
# Out:
#        company_size_employees  years_experience_min  years_experience_max  \
# count           115000.000000         115000.000000         115000.000000
# mean            105386.103122              3.004452              6.665443
# std             102117.290040              3.093383              5.073654
# min                 10.000000              0.000000              0.000000
# 25%               6038.750000              1.000000              3.000000
# 50%              88364.000000              2.000000              6.000000
# 75%             169840.250000              5.000000              9.000000
# max             488674.000000             24.000000             24.000000
#
#        number_of_applicants  number_of_interview_rounds  offers_extended  \
# count         113890.000000               114564.000000    114670.000000
# mean             181.659215                    3.307653         1.349786
# std              436.344753                    1.418283         1.457267
# min               -5.000000                    1.000000         0.000000
# 25%               62.000000                    2.000000         1.000000
# 50%              119.000000                    3.000000         1.000000
# 75%              213.000000                    4.000000         1.000000
# max            36816.000000                    8.000000         8.000000
#
#        offers_accepted
# count    114670.000000
# mean          1.196634
# std           1.122837
# min           0.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max          10.000000

# %%
df.isnull().sum().sum()
# Out:
# np.int64(87962)

# %% [markdown]
# there are 87962 missing value in the data

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# date_position_filled            25781
# job_location_city               25107
# primary_programming_language    22475
# application_deadline             5757
# salary_max_usd                   3318
# salary_min_usd                   3318
# number_of_applicants             1110
# number_of_interview_rounds        436
# offers_accepted                   330
# offers_extended                   330
# company_type                        0
# job_id                              0
# required_tech_stack                 0
# years_experience_max                0
# years_experience_min                0
# seniority_level                     0
# hq_country                          0
# job_role                            0
# company_size_employees              0
# sector                              0
# company_name                        0
# salary_currency                     0
# visa_sponsorship_offered            0
# job_location_country                0
# work_mode                           0
# posting_date                        0
# position_status                     0
# layoff_within_12_months_flag        0
# dtype: int64

# %% [markdown]
# There are missing values in several columns. For example, date_position_filled, job_location_city and primary_programming_language have many missing values.

# %%
null_table = pd.DataFrame({"Null Values": df.isnull().sum(), "Percentage": (df.isnull().sum() / len(df)) * 100 })
print(null_table)
# Out:
#                               Null Values  Percentage
# job_id                                  0    0.000000
# company_name                            0    0.000000
# company_type                            0    0.000000
# sector                                  0    0.000000
# company_size_employees                  0    0.000000
# hq_country                              0    0.000000
# job_role                                0    0.000000
# seniority_level                         0    0.000000
# years_experience_min                    0    0.000000
# years_experience_max                    0    0.000000
# required_tech_stack                     0    0.000000
# primary_programming_language        22475   19.543478
# work_mode                               0    0.000000
# visa_sponsorship_offered                0    0.000000
# job_location_country                    0    0.000000
# job_location_city                   25107   21.832174
# salary_currency                         0    0.000000
# posting_date                            0    0.000000
# application_deadline                 5757    5.006087
# date_position_filled                25781   22.418261
# position_status                         0    0.000000
# number_of_applicants                 1110    0.965217
# number_of_interview_rounds            436    0.379130
# offers_extended                       330    0.286957
# offers_accepted                       330    0.286957
# salary_min_usd                       3318    2.885217
# salary_max_usd                       3318    2.885217
# layoff_within_12_months_flag            0    0.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(1193)

# %%
df = df.drop_duplicates()

# %% [markdown]
# duplicates are removed

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (113807, 28)

# %%
print(df[df["number_of_applicants"] < 0])
# Out:
#            job_id               company_name company_type         sector  \
# 828     JOB047519             CatalystHub Co      Unicorn          AI/ML
# 999     JOB089620                NexusShield          MNC     E-commerce
# 1186    JOB017460             BeaconStack Co          MNC          AI/ML
# 1367    JOB022767        PinnacleLedger Labs   FAANG-tier  Social/AdTech
# 2079    JOB026375  VertexNeural Technologies      Unicorn     E-commerce
# ...           ...                        ...          ...            ...
# 114361  JOB106646                AetherAI Co          MNC          AI/ML
# 114362  JOB087848               OnyxBuzz Inc      Unicorn  Social/AdTech
# 114442  JOB044471                AetherAI Co          MNC          AI/ML
# 114496  JOB015455                 OrbitWorks      Unicorn     HealthTech
# 114542  JOB109085             OnyxBuzz Inc        Unicorn  Social/AdTech
#
#         company_size_employees hq_country                   job_role  \
# 828                       3938    Ireland          Frontend Engineer
# 999                     332916      India          Software Engineer
# 1186                    210343        USA  Technical Program Manager
# 1367                     88716        USA          Frontend Engineer
# 2079                      9511        USA  Mobile Engineer (Android)
# ...                        ...        ...                        ...
# 114361                  233311         UK              Product Owner
# 114362                   13453        USA          Frontend Engineer
# 114442                  287824         UK          Software Engineer
# 114496                    9585     Israel          Security Engineer
# 114542                   15224        USA             Data Scientist
#
#        seniority_level  years_experience_min  years_experience_max  ...  \
# 828              Entry                     0                     1  ...
# 999               Lead                     8                    16  ...
# 1186               Mid                     3                     5  ...
# 1367            Senior                     6                     9  ...
# 2079             Entry                     1                     3  ...
# ...                ...                   ...                   ...  ...
# 114361           Entry                     0                     1  ...
# 114362            Lead                     9                    16  ...
# 114442             Mid                     3                     5  ...
# 114496             Mid                     1                     7  ...
# 114542            Lead                     7                    16  ...
#
#        application_deadline date_position_filled position_status  \
# 828     2023-06-11 00:00:00           2023-05-22          Filled
# 999     2020-02-28 00:00:00           2020-02-18          Filled
# 1186    2024-06-02 00:00:00           2024-06-09          Filled
# 1367    2024-11-16 00:00:00                  NaN       Cancelled
# 2079    2025-03-08 00:00:00                  NaN            Open
# ...                     ...                  ...             ...
# 114361  2026-04-28 00:00:00           2026-04-20          Filled
# 114362  2026-02-22 00:00:00                  NaN            Open
# 114442  2024-12-17 00:00:00                  NaN       Cancelled
# 114496  2025-12-08 00:00:00           2025-11-21          Filled
# 114542  2019-11-21 00:00:00           2019-12-02          Filled
#
#        number_of_applicants number_of_interview_rounds offers_extended  \
# 828                    -5.0                        3.0             1.0
# 999                    -1.0                        5.0             1.0
# 1186                   -5.0                        2.0             1.0
# 1367                   -5.0                        6.0             1.0
# 2079                   -5.0                        1.0             1.0
# ...                     ...                        ...             ...
# 114361                 -5.0                        3.0             1.0
# 114362                 -1.0                        4.0             1.0
# 114442                 -5.0                        2.0             1.0
# 114496                 -5.0                        3.0             1.0
# 114542                 -5.0                        5.0             1.0
#
#        offers_accepted salary_min_usd salary_max_usd  \
# 828                1.0       101300.0       116300.0
# 999                1.0       147500.0       179400.0
# 1186               1.0       140400.0       159900.0
# 1367               1.0       233500.0       267100.0
# 2079               1.0        69800.0        86800.0
# ...                ...            ...            ...
# 114361             1.0        82400.0        90100.0
# 114362             1.0            NaN            NaN
# 114442             0.0       200000.0       267400.0
# 114496             1.0       101800.0       135400.0
# 114542             1.0       161300.0       202700.0
#
#        layoff_within_12_months_flag
# 828                               0
# 999                               N
# 1186                             No
# 1367                             No
# 2079                          False
# ...                             ...
# 114361                            N
# 114362                        False
# 114442                        False
# 114496                         True
# 114542                           No
#
# [243 rows x 28 columns]

# %%
df["company_name"] = df["company_name"].str.strip()
df["job_role"] = df["job_role"].str.strip()
df["sector"] = df["sector"].str.strip()
df["company_type"] = df["company_type"].str.strip()
df["work_mode"] = df["work_mode"].str.strip()

# %%
df["salary_min_usd"] = (
    df["salary_min_usd"]
    .astype(str)
    .str.replace("$", "")
    .str.replace(",", ""))

# %%
df["salary_min_usd"] = pd.to_numeric(
    df["salary_min_usd"], errors="coerce")

# %% [markdown]
# converting  min salary into nymbers

# %%
df["salary_max_usd"] = (
    df["salary_max_usd"].astype(str)
    .str.replace("$", "")
    .str.replace(",", ""))

# %%
df["salary_max_usd"] = pd.to_numeric(
    df["salary_max_usd"], errors="coerce")

# %% [markdown]
# converting max salary into numbers

# %%
print(df["salary_min_usd"].dtype)
print(df["salary_max_usd"].dtype)
# Out:
# float64
# float64

# %%
df
# Out:
#            job_id              company_name company_type         sector  \
# 0       JOB041385              CobaltWealth          MNC     HealthTech
# 1       JOB018462                DriftLearn     Mid-size    Cloud/Infra
# 2       JOB110011           AnchorBuzz Labs          MNC     HealthTech
# 3       JOB073462                KiteSphere      Unicorn     HealthTech
# 4       JOB051683             AetherNode Co          MNC  Social/AdTech
# ...           ...                       ...          ...            ...
# 114995  JOB012896   EmberReach Technologies   FAANG-tier     HealthTech
# 114996  JOB060961                AstraSuite          MNC     HealthTech
# 114997  JOB006013          MeridianLogix Co      Startup        Fintech
# 114998  JOB063108                WrenCampus     Mid-size  Cybersecurity
# 114999  JOB006559  QuantumBuzz Technologies          MNC           SaaS
#
#         company_size_employees hq_country                   job_role  \
# 0                       146085    Germany                SOC Analyst
# 1                         5882        USA      Mobile Engineer (iOS)
# 2                       186507        USA                QA Engineer
# 3                        10930     Brazil         Research Scientist
# 4                        42510        USA            Product Manager
# ...                        ...        ...                        ...
# 114995                   57977         UK          Software Engineer
# 114996                  163658     Brazil             Data Scientist
# 114997                     473     Canada         Analytics Engineer
# 114998                    5425      India  Technical Program Manager
# 114999                  108163         UK           Backend Engineer
#
#        seniority_level  years_experience_min  years_experience_max  ...  \
# 0                  Mid                     3                     5  ...
# 1                  Mid                     1                     4  ...
# 2                 Lead                     7                    15  ...
# 3                Entry                     1                     4  ...
# 4               Senior                     6                     9  ...
# ...                ...                   ...                   ...  ...
# 114995            Lead                     7                    16  ...
# 114996          Senior                     4                    10  ...
# 114997             Mid                     2                     6  ...
# 114998          Senior                     5                     8  ...
# 114999             Mid                     3                     6  ...
#
#        application_deadline date_position_filled position_status  \
# 0       2023-11-12 00:00:00           2023-11-20          Filled
# 1       2025-06-29 00:00:00                  NaN            Open
# 2       2026-01-24 00:00:00           2026-02-08          Filled
# 3       2020-12-09 00:00:00           2020-12-21          Filled
# 4       2025-07-19 00:00:00           2025-09-15          Filled
# ...                     ...                  ...             ...
# 114995  2025-11-14 00:00:00           2025-12-21          Filled
# 114996                  NaN                  NaN            Open
# 114997  2024-02-09 00:00:00                  NaN       Cancelled
# 114998  2024-09-04 00:00:00                  NaN            Open
# 114999  2021-01-02 00:00:00           2021-02-16          Filled
#
#        number_of_applicants number_of_interview_rounds offers_extended  \
# 0                      98.0                        4.0             5.0
# 1                     134.0                        2.0             1.0
# 2                      36.0                        4.0             1.0
# 3                     300.0                        1.0             6.0
# 4                      43.0                        3.0             1.0
# ...                     ...                        ...             ...
# 114995                 45.0                        6.0             1.0
# 114996                 57.0                        4.0             1.0
# 114997                141.0                        3.0             1.0
# 114998                 78.0                        4.0             1.0
# 114999                 48.0                        4.0             1.0
#
#        offers_accepted salary_min_usd salary_max_usd  \
# 0                  5.0           -1.0           -1.0
# 1                  0.0            NaN            NaN
# 2                  1.0       238800.0       274700.0
# 3                  5.0        96300.0       104000.0
# 4                  1.0       186800.0       245400.0
# ...                ...            ...            ...
# 114995             1.0       215300.0       254300.0
# 114996             0.0        87500.0       113500.0
# 114997             1.0       126000.0       156400.0
# 114998             1.0       156000.0       174100.0
# 114999             1.0       120400.0       147000.0
#
#        layoff_within_12_months_flag
# 0                                 N
# 1                                No
# 2                                 0
# 3                               Yes
# 4                                 1
# ...                             ...
# 114995                          Yes
# 114996                            0
# 114997                            N
# 114998                           No
# 114999                            N
#
# [113807 rows x 28 columns]

# %%
print(df[df["salary_min_usd"] <= 0])
# Out:
#            job_id              company_name company_type         sector  \
# 0       JOB041385              CobaltWealth          MNC     HealthTech
# 64      JOB032795            DriftSkill Inc          MNC     E-commerce
# 334     JOB086698           AnchorBuzz Labs          MNC     HealthTech
# 357     JOB042858            BeaconStack Co          MNC          AI/ML
# 628     JOB072304            AstraCognition      Unicorn     HealthTech
# ...           ...                       ...          ...            ...
# 114319  JOB086202         RidgeFreight Labs          MNC         EdTech
# 114371  JOB083271              KitePlay Inc     Mid-size      Logistics
# 114435  JOB085672              CobaltWealth          MNC     HealthTech
# 114562  JOB072567  QuantumBuzz Technologies          MNC           SaaS
# 114903  JOB017173       PinnacleLedger Labs   FAANG-tier  Social/AdTech
#
#         company_size_employees   hq_country                   job_role  \
# 0                       146085      Germany                SOC Analyst
# 64                      133192       Canada                QA Engineer
# 334                     197174          USA         Research Scientist
# 357                     259183          USA             Cloud Engineer
# 628                      16415  Netherlands  Embedded Systems Engineer
# ...                        ...          ...                        ...
# 114319                  299539           UK         Penetration Tester
# 114371                    5835          USA              Data Engineer
# 114435                  133638      Germany           Backend Engineer
# 114562                   86808           UK          Platform Engineer
# 114903                   72524          USA          Frontend Engineer
#
#        seniority_level  years_experience_min  years_experience_max  ...  \
# 0                  Mid                     3                     5  ...
# 64               Entry                     1                     1  ...
# 334              Entry                     0                     3  ...
# 357                Mid                     1                     7  ...
# 628                Mid                     1                     6  ...
# ...                ...                   ...                   ...  ...
# 114319           Entry                     0                     2  ...
# 114371             Mid                     3                     7  ...
# 114435             Mid                     2                     5  ...
# 114562           Entry                     0                     2  ...
# 114903           Entry                     0                     3  ...
#
#        application_deadline date_position_filled position_status  \
# 0       2023-11-12 00:00:00           2023-11-20          Filled
# 64      2026-03-03 00:00:00           2026-03-05          Filled
# 334     2024-10-25 00:00:00           2024-11-07          Filled
# 357       Open Until Filled           2024-08-23          Filled
# 628     2020-11-07 00:00:00           2020-11-13          Filled
# ...                     ...                  ...             ...
# 114319  2025-11-14 00:00:00           2025-12-06          Filled
# 114371  2024-01-21 00:00:00           2024-02-15          Filled
# 114435  2022-07-11 00:00:00           2022-08-13          Filled
# 114562  2025-04-21 00:00:00           2025-07-23          Filled
# 114903  2020-04-20 00:00:00           2020-02-22          Filled
#
#        number_of_applicants number_of_interview_rounds offers_extended  \
# 0                      98.0                        4.0             5.0
# 64                    194.0                        1.0             1.0
# 334                   531.0                        2.0             1.0
# 357                   148.0                        2.0             1.0
# 628                   111.0                        2.0             1.0
# ...                     ...                        ...             ...
# 114319                322.0                        3.0             1.0
# 114371                189.0                        3.0             1.0
# 114435                 70.0                        3.0             1.0
# 114562                262.0                        1.0             1.0
# 114903                288.0                        4.0             5.0
#
#        offers_accepted salary_min_usd salary_max_usd  \
# 0                  5.0           -1.0           -1.0
# 64                 1.0           -1.0           -1.0
# 334                1.0           -1.0           -1.0
# 357                1.0           -1.0           -1.0
# 628                1.0           -1.0           -1.0
# ...                ...            ...            ...
# 114319             1.0           -1.0           -1.0
# 114371             1.0           -1.0           -1.0
# 114435             1.0           -1.0           -1.0
# 114562             1.0           -1.0           -1.0
# 114903             5.0           -1.0           -1.0
#
#        layoff_within_12_months_flag
# 0                                 N
# 64                                N
# 334                            True
# 357                              No
# 628                             Yes
# ...                             ...
# 114319                         True
# 114371                        False
# 114435                            0
# 114562                            N
# 114903                           No
#
# [727 rows x 28 columns]

# %%
df.loc[df["salary_min_usd"] <= 0, "salary_min_usd"] = np.nan
df.loc[df["salary_max_usd"] <= 0, "salary_max_usd"] = np.nan

# %%
print(df["years_experience_min"].min())
print(df["years_experience_max"].max())
# Out:
# 0
# 24

# %%
df.loc[df["years_experience_min"] > df["years_experience_max"],["years_experience_min", "years_experience_max"]] = np.nan

# %% [markdown]
# minimum experience should not be greater than maximum experience

# %%
df.loc[df["number_of_applicants"] < 0,"number_of_applicants"] = np.nan

# %%
for col in ["posting_date", "application_deadline", "date_position_filled"]:
    df[col] = pd.to_datetime(df[col], errors="coerce")

# %% [markdown]
# converting date columns into proper date format

# %%
cols = ["salary_min_usd", "salary_max_usd", "number_of_applicants", "number_of_interview_rounds", "offers_extended", "offers_accepted"]

df[cols] = df[cols].fillna(df[cols].median())

# %% [markdown]
# filling all the numerical value with median

# %%
df["layoff_within_12_months_flag"] = df["layoff_within_12_months_flag"].map({'N':"No", '0' : "No", '1' : "Yes" ,'False':"No" ,'Y':"Yes", 'True':"Yes"})
df["visa_sponsorship_offered"] = df["visa_sponsorship_offered"].map({'N':"No", '0' : "No", '1' : "Yes" ,'False':"No" ,'Y':"Yes", 'True':"Yes"})

print(df["layoff_within_12_months_flag"].unique())
print(df["visa_sponsorship_offered"].unique())
# Out:
# ['No' nan 'Yes']
# ['No' nan 'Yes']

# %%
df["primary_programming_language"] = df["primary_programming_language"].fillna("unknown")

# %%
df["job_location_city"] = df["job_location_city"].fillna("Unknown")

# %%
print(df.isnull().sum())
# Out:
# job_id                              0
# company_name                        0
# company_type                        0
# sector                              0
# company_size_employees              0
# hq_country                          0
# job_role                            0
# seniority_level                     0
# years_experience_min              315
# years_experience_max              315
# required_tech_stack                 0
# primary_programming_language        0
# work_mode                           0
# visa_sponsorship_offered        28347
# job_location_country                0
# job_location_city                   0
# salary_currency                     0
# posting_date                        0
# application_deadline            11275
# date_position_filled            25514
# position_status                     0
# number_of_applicants                0
# number_of_interview_rounds          0
# offers_extended                     0
# offers_accepted                     0
# salary_min_usd                      0
# salary_max_usd                      0
# layoff_within_12_months_flag    28285
# dtype: int64

# %% [markdown]
# ###Feature engineering

# %%
df["average_salary"] = (df["salary_min_usd"] +df["salary_max_usd"]) / 2

# %% [markdown]
# avg salary

# %%
df["average_experience"] = (df["years_experience_min"] + df["years_experience_max"]) / 2

# %% [markdown]
# avg experience

# %%
df["experience_range"] = (df["years_experience_max"] - df["years_experience_min"])

# %% [markdown]
# how much person have experience

# %%
df["posting_year"] = df["posting_date"].dt.year

# %% [markdown]
# we can extract year in which job opening has been released

# %%
df["posting_month"] = df["posting_date"].dt.month

# %% [markdown]
# what is the major posting time

# %%
df.describe()
# Out:
#        company_size_employees  years_experience_min  years_experience_max  \
# count           113807.000000         113492.000000         113492.000000
# mean            105407.621552              2.991947              6.673228
# min                 10.000000              0.000000              0.000000
# 25%               6044.500000              1.000000              3.000000
# 50%              88378.000000              2.000000              6.000000
# 75%             169835.500000              5.000000              9.000000
# max             488674.000000             13.000000             24.000000
# std             102128.678701              3.075278              5.073103
#
#                         posting_date           application_deadline  \
# count                         113807                         102532
# mean   2023-05-13 03:22:48.137284864  2023-06-18 22:23:38.483985408
# min              2019-01-01 00:00:00            2019-01-16 00:00:00
# 25%              2021-07-01 00:00:00            2021-08-06 00:00:00
# 50%              2023-11-07 00:00:00            2023-12-13 00:00:00
# 75%              2025-04-26 00:00:00            2025-06-04 00:00:00
# max              2026-08-29 00:00:00            2026-10-27 00:00:00
# std                              NaN                            NaN
#
#                 date_position_filled  number_of_applicants  \
# count                          88293         113807.000000
# mean   2023-06-16 13:40:00.040773376            181.431248
# min              2019-01-03 00:00:00              0.000000
# 25%              2021-08-07 00:00:00             63.000000
# 50%              2023-12-10 00:00:00            119.000000
# 75%              2025-05-30 00:00:00            212.000000
# max              2026-09-03 00:00:00          36816.000000
# std                              NaN            435.641006
#
#        number_of_interview_rounds  offers_extended  offers_accepted  \
# count               113807.000000    113807.000000    113807.000000
# mean                     3.306352         1.348291         1.195849
# min                      1.000000         0.000000         0.000000
# 25%                      2.000000         1.000000         1.000000
# 50%                      3.000000         1.000000         1.000000
# 75%                      4.000000         1.000000         1.000000
# max                      8.000000         8.000000        10.000000
# std                      1.415474         1.454451         1.120861
#
#        salary_min_usd  salary_max_usd  average_salary  average_experience  \
# count   113807.000000    1.138070e+05    1.138070e+05       113492.000000
# mean    115002.469532    1.420723e+05    1.285374e+05            4.832587
# min       1700.000000    1.590000e+04    1.030000e+04            0.000000
# 25%      78000.000000    9.420000e+04    8.630000e+04            2.000000
# 50%     105900.000000    1.287000e+05    1.173000e+05            4.000000
# 75%     143600.000000    1.750000e+05    1.594250e+05            7.000000
# max     531800.000000    3.552000e+06    1.910150e+06           18.500000
# std      55760.573626    8.935350e+04    6.827420e+04            4.019485
#
#        experience_range   posting_year  posting_month
# count     113492.000000  113807.000000  113807.000000
# mean           3.681282    2022.918212       5.895033
# min            0.000000    2019.000000       1.000000
# 25%            2.000000    2021.000000       3.000000
# 50%            3.000000    2023.000000       6.000000
# 75%            5.000000    2025.000000       9.000000
# max           13.000000    2026.000000      12.000000
# std            2.400498       2.253067       3.370418

# %% [markdown]
# UNIVARIATE ANALYSIS

# %%
top_roles = df["job_role"].value_counts().head(10)
top_roles.plot(kind="bar")
plt.title("Top 10 Job Roles")
plt.xlabel("Job Role")
plt.ylabel("Number of Jobs")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# how many jobs are present in which field

# %%
df["work_mode"] = df["work_mode"].replace({
    "REMOTE": "Remote",
    "remote": "Remote",
    "WFH": "Remote",
    "Work From Home": "Remote",
    "HYBRID": "Hybrid",
    "hybrid": "Hybrid",
    "ONSITE": "Onsite",
    "onsite": "Onsite",
    "In-office": "Onsite",
    "On-site": "Onsite"
})

# %%
df["work_mode"].value_counts().plot(kind="bar")
plt.title("Job Postings by Work Mode")
plt.xlabel("Work Mode")
plt.ylabel("Number of Jobs")
plt.show()

# %% [markdown]
# no. of jobs present in which mode mainly

# %%
df["primary_programming_language"].value_counts().head(10).plot(kind="bar")
plt.title("Top Programming Languages")
plt.xlabel("Programming Language")
plt.ylabel("Number of Jobs")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# most of people have unknown language and after that most common language is python, it helps us to know which language is how much used

# %%
df["seniority_level"].value_counts().plot(kind="bar")
plt.title("Jobs by Seniority Level")
plt.xlabel("Seniority Level")
plt.ylabel("Number of Jobs")
plt.show()

# %% [markdown]
# jobs which are present at differnt level

# %%
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
sns.histplot(df['number_of_interview_rounds'], bins=30)
plt.title('Distribution of Number of Interview Rounds')
plt.show()

# %% [markdown]
# most of company conduct 2-4 interview rounds

# %%
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
sns.histplot(df['years_experience_max'], bins=30)
plt.title('Distribution of Years of Experience (Maximum)')
plt.show()

# %% [markdown]
# Most comapny needed experience is mostly 1-10 year but there are company that needed more expierenced employee

# %% [markdown]
# ###Bivariate Analysis

# %%
plt.figure(figsize=(8,5))
sample = df.sample(3000, random_state=42)
plt.scatter(
    sample["average_experience"],
    sample["average_salary"],
    alpha=0.3 )
plt.title("Salary vs Experience")
plt.xlabel("Average Experience")
plt.ylabel("Average Salary")
plt.show()

# %%
print(
    df["average_experience"].corr(
        df["average_salary"]))
# Out:
# 0.6978257800702339

# %% [markdown]
# salary has a strong  positive corelation with experience, means  more experience offer higher salary

# %%
sns.boxplot(
 data=df,
 x="seniority_level",
 y="average_salary")
plt.title("Salary by Seniority Level")
plt.xlabel("Seniority Level")
plt.ylabel("Average Salary")
plt.show()

# %% [markdown]
# salary generally increase as seniority level increases

# %%
plt.figure(figsize=(8,6))
sns.countplot(data=df, x='sector', hue='layoff_within_12_months_flag')
plt.title('Layoffs by Sector')
plt.xticks(rotation=90)
plt.show()

# %%
df.groupby("work_mode")["average_salary"].mean().plot(kind="bar")
plt.title("Average Salary by Work Mode")
plt.xlabel("Work Mode")
plt.ylabel("Average Salary")

plt.show()

# %% [markdown]
# avg salary is same for hybrid, onsite and remote

# %%
pd.crosstab(
df["seniority_level"],
df["work_mode"]).plot(kind="bar")
plt.title("Seniority Level vs Work Mode")
plt.xlabel("Seniority Level")
plt.ylabel("Number of Jobs")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# this graph shows which seniority level has how many no. of jobs

# %% [markdown]
# ###Multivariate Analysis

# %%
table = pd.pivot_table(df,
values="average_salary",
index="seniority_level",
columns="work_mode",
aggfunc="mean")
print(table)
# Out:
# work_mode               Hybrid         Onsite         Remote
# seniority_level
# Entry             86204.195456   86588.416667   86378.640623
# Intern            37363.977608   38268.539710   37929.790985
# Lead             201552.915950  202769.046770  202146.797242
# Mid              122144.842311  122309.468030  122706.602459
# Principal        248260.155718  251930.030541  247949.711316
# Senior           169926.807182  171022.092173  171671.198069

# %%
plt.figure(figsize=(8,5))
sns.heatmap(
table,
annot=True,
fmt=".0f")
plt.title("Average Salary by Seniority and Work Mode")
plt.xlabel("Work Mode")
plt.ylabel("Seniority Level")
plt.show()

# %% [markdown]
# seniority has a much stronger effect on salry than work mode

# %%
num_cols = [
    "average_salary",
    "average_experience",
    "number_of_applicants",
    "number_of_interview_rounds",
    "offers_extended",
    "offers_accepted"]

# %%
plt.figure(figsize=(9,6))
sns.heatmap(df[num_cols].corr(),
annot=True,
fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# showing how these features are related with each other

# %%
sector_salary = df.groupby("sector")
["average_salary"].mean().sort_values(ascending=False)
sector_salary.plot(kind="bar")
plt.title("Average Salary by Sector")
plt.xlabel("Sector")
plt.ylabel("Average Salary")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# AI/ML and crypto/web3 has higher salary among other fields

# %%
df.groupby("number_of_interview_rounds")["average_salary"].mean().plot(
 kind="line",
marker="o")
plt.title("Average Salary vs Number of Interview Rounds")
plt.xlabel("Interview Rounds")
plt.ylabel("Average Salary")
plt.show()

# %% [markdown]
# jobs with more interview round generally have high salary

# %% [markdown]
# Time Series Analysis

# %%
df["posting_year"] = df["posting_date"].dt.year

# %%
yearly_jobs = df.groupby("posting_year").size()
print(yearly_jobs)
# Out:
# posting_year
# 2019    11468
# 2020     9680
# 2021    13656
# 2022    13490
# 2023    10383
# 2024    19252
# 2025    20480
# 2026    15398
# dtype: int64

# %%
plt.figure(figsize=(9,5))
plt.plot(
yearly_jobs.index,
yearly_jobs.values,
marker="o")
plt.title("Job Postings Over Time")
plt.xlabel("Year")
plt.ylabel("Number of Job Postings")
plt.grid()
plt.show()

# %% [markdown]
# this shows that 2025 has higher no. of job posting than other

# %%
monthly_jobs = df.groupby(df["posting_date"].dt.to_period("M")).size()

# %%
plt.figure(figsize=(16,4))
plt.plot(
    monthly_jobs.index.astype(str),
    monthly_jobs.values)
plt.title("Monthly Job Posting Trend")
plt.xlabel("Month")
plt.ylabel("Number of Job Postings")
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# monthly jobs posting show that how hiring changes throughout the year
